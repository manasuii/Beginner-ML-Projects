# %% [markdown]
# <a href="https://colab.research.google.com/github/manasuii/Beginner-ML-Projects/blob/main/Mass_Spring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym
import numpy as np

class PIDEnv(gym.Env):
    def __init__(self):
        super(PIDEnv, self).__init__()

        self.observation_space = gym.spaces.Box(
            low=np.array([-10, -10, -10], dtype=np.float32),
            high=np.array([10, 10, 10], dtype=np.float32)
        )

        self.action_space = gym.spaces.Box(
            low=np.array([-5.0], dtype=np.float32),
            high=np.array([5.0], dtype=np.float32)
        )

        self.setpoint = 1.0
        self.process_variable = 0.0
        self.prev_error = 0.0
        self.integral = 0.0

    def reset(self, seed=None, options=None):
        self.process_variable = np.random.uniform(0, 0.2)
        self.prev_error = 0.0
        self.integral = 0.0

        error = self.setpoint - self.process_variable
        state = np.array([error, self.integral, 0.0], dtype=np.float32)

        return state, {}

    def step(self, action):
        action = float(action)

        self.process_variable += 0.1 * action
        self.process_variable = np.clip(self.process_variable, -2, 2)

        error = self.setpoint - self.process_variable
        derivative = error - self.prev_error
        self.integral += error

        reward = -abs(error)

        terminated = abs(error) < 0.01

        self.prev_error = error

        state = np.array([error, self.integral, derivative], dtype=np.float32)

        return state, reward, terminated, False, {}

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

env = DummyVecEnv([lambda: PIDEnv()])

model = PPO(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=0.0003,
    n_steps=2048,
    batch_size=64,
)

model.learn(total_timesteps=50_000)
model.save("pid_rl_agent")
# Out:
# Using cpu device
# /tmp/ipython-input-2311706435.py:34: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   action = float(action)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# -----------------------------
# | time/              |      |
# |    fps             | 1408 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 970          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0065582204 |
# |    clip_fraction        | 0.0879       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.016       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 196          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00808     |
# |    std                  | 0.992        |
# |    value_loss           | 466          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 3            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0066500166 |
# |    clip_fraction        | 0.094        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.429        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.2         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00908     |
# |    std                  | 0.975        |
# |    value_loss           | 115          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 4            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0065240613 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.456        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.2         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00552     |
# |    std                  | 0.989        |
# |    value_loss           | 38.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 748          |
# |    iterations           | 5            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0024378966 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.279        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.9         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00104     |
# |    std                  | 0.982        |
# |    value_loss           | 28.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010891413 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -0.0551     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00849    |
# |    std                  | 0.972       |
# |    value_loss           | 32.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010412187 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.4        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00807    |
# |    std                  | 0.952       |
# |    value_loss           | 29.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 714          |
# |    iterations           | 8            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0064797937 |
# |    clip_fraction        | 0.0831       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.062        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.88         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00623     |
# |    std                  | 0.941        |
# |    value_loss           | 17.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 717         |
# |    iterations           | 9           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011772744 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0583      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.51        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.927       |
# |    value_loss           | 11.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 10          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010583313 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0664      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.44        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.889       |
# |    value_loss           | 6.07        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 715         |
# |    iterations           | 11          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.016692959 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.113       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.92        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.838       |
# |    value_loss           | 3.32        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 12          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017248368 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.275       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.667       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 0.79        |
# |    value_loss           | 1.45        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 13          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015591127 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.248       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0201     |
# |    std                  | 0.737       |
# |    value_loss           | 0.624       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 695        |
# |    iterations           | 14         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01749792 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.445      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.225      |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0227    |
# |    std                  | 0.679      |
# |    value_loss           | 0.376      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 690        |
# |    iterations           | 15         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.02226388 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.986     |
# |    explained_variance   | 0.531      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.039      |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0305    |
# |    std                  | 0.626      |
# |    value_loss           | 0.236      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 687         |
# |    iterations           | 16          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.020888142 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.897      |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0527      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.03       |
# |    std                  | 0.571       |
# |    value_loss           | 0.138       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 690        |
# |    iterations           | 17         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.02000329 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.807     |
# |    explained_variance   | 0.747      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0148    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0324    |
# |    std                  | 0.521      |
# |    value_loss           | 0.0798     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 693         |
# |    iterations           | 18          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.017595138 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.716      |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0262     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0279     |
# |    std                  | 0.477       |
# |    value_loss           | 0.0712      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 694         |
# |    iterations           | 19          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.019091833 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0388     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0303     |
# |    std                  | 0.437       |
# |    value_loss           | 0.0637      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 687         |
# |    iterations           | 20          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.020696029 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.545      |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0525     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0291     |
# |    std                  | 0.399       |
# |    value_loss           | 0.0374      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 688         |
# |    iterations           | 21          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.018598711 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.455      |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0184     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.029      |
# |    std                  | 0.368       |
# |    value_loss           | 0.0275      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 692         |
# |    iterations           | 22          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.018433724 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.374      |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0396     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0408     |
# |    std                  | 0.338       |
# |    value_loss           | 0.0154      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 23          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.019927107 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.295      |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0323     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0358     |
# |    std                  | 0.313       |
# |    value_loss           | 0.0146      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 682         |
# |    iterations           | 24          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.025022436 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.217      |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0683     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0433     |
# |    std                  | 0.29        |
# |    value_loss           | 0.0116      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 683         |
# |    iterations           | 25          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.017588805 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.141      |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.03       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0376     |
# |    std                  | 0.269       |
# |    value_loss           | 0.00901     |
# -----------------------------------------

# %%
model = PPO.load("pid_rl_agent")

env = PIDEnv()
obs, _ = env.reset()

for step in range(50):
    action, _ = model.predict(obs)
    obs, reward, done, _, _ = env.step(action)
    print(f"Step {step}, PV={env.process_variable:.3f}, Reward={reward:.3f}")
    if done:
        print("Target reached!")
        break
# Out:
# Step 0, PV=0.497, Reward=-0.503
# Step 1, PV=0.779, Reward=-0.221
# Step 2, PV=1.000, Reward=-0.000
# Target reached!
# /tmp/ipython-input-2311706435.py:34: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   action = float(action)
